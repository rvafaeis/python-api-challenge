# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | redmond
# Processing Record 5 of Set 1 | port macquarie
# Processing Record 6 of Set 1 | lujan
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | la libertad
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | matara
# Processing Record 12 of Set 1 | opunake
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 1 | puerto madero
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | nuuk
# Processing Record 18 of Set 1 | svetlyy
# Processing Record 19 of Set 1 | sao joao da barra
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | sistranda
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | ferrol
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | marolambo
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | iquitos
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | atamanovka
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | silver city
# Processing Record 39 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 1 | lipari
# Processing Record 48 of Set 1 | bathsheba
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | airai
# Processing Record 0 of Set 2 | albany
# Processing Record 1 of Set 2 | sioux lookout
# Processing Record 2 of Set 2 | sitka
# Processing Record 3 of Set 2 | bahir dar
# Processing Record 4 of Set 2 | nieuw nickerie
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | nanning
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | cervo
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 14 of Set 2 | brenham
# Processing Record 15 of Set 2 | aranos
# Processing Record 16 of Set 2 | alofi
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | oussouye
# Processing Record 19 of Set 2 | pipri
# Processing Record 20 of Set 2 | katima mulilo
# Processing Record 21 of Set 2 | la ronge
# Processing Record 22 of Set 2 | araouane
# Processing Record 23 of Set 2 | korla
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | palmer
# Processing Record 26 of Set 2 | kirksville
# Processing Record 27 of Set 2 | bam
# Processing Record 28 of Set 2 | kingston
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 31 of Set 2 | codrington
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | koryazhma
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | nueva helvecia
# Processing Record 36 of Set 2 | coihaique
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | palasa
# Processing Record 39 of Set 2 | iskateley
# Processing Record 40 of Set 2 | salina cruz
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | kilindoni
# Processing Record 0 of Set 3 | grindavik
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | beroroha
# Processing Record 3 of Set 3 | ayan
# Processing Record 4 of Set 3 | khasan
# Processing Record 5 of Set 3 | bandarbeyla
# Processing Record 6 of Set 3 | waingapu
# Processing Record 7 of Set 3 | anadyr
# Processing Record 8 of Set 3 | vardo
# Processing Record 9 of Set 3 | port-gentil
# Processing Record 10 of Set 3 | tsuyama
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | aracoiaba da serra
# Processing Record 13 of Set 3 | beypur
# City not found. Skipping...
# Processing Record 14 of Set 3 | portobelo
# Processing Record 15 of Set 3 | lompoc
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | fez
# Processing Record 18 of Set 3 | lasa
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | biak
# Processing Record 21 of Set 3 | aasiaat
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | rockland
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | sept-iles
# Processing Record 26 of Set 3 | lata
# Processing Record 27 of Set 3 | abnub
# Processing Record 28 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 3 | san patricio
# Processing Record 30 of Set 3 | le port
# Processing Record 31 of Set 3 | comodoro rivadavia
# Processing Record 32 of Set 3 | celestun
# Processing Record 33 of Set 3 | dakar
# Processing Record 34 of Set 3 | pingliang
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | abadiania
# Processing Record 37 of Set 3 | andenes
# Processing Record 38 of Set 3 | baruun-urt
# Processing Record 39 of Set 3 | raudeberg
# Processing Record 40 of Set 3 | dargaville
# Processing Record 41 of Set 3 | shelburne
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | three hills
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | odweyne
# Processing Record 46 of Set 3 | te anau
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | veydelevka
# Processing Record 49 of Set 3 | hambantota
# Processing Record 0 of Set 4 | alvorada
# Processing Record 1 of Set 4 | namibe
# Processing Record 2 of Set 4 | fukue
# Processing Record 3 of Set 4 | narrabri
# Processing Record 4 of Set 4 | north platte
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | kharovsk
# Processing Record 7 of Set 4 | kavieng
# Processing Record 8 of Set 4 | saint-pierre
# Processing Record 9 of Set 4 | morondava
# Processing Record 10 of Set 4 | mount pleasant
# Processing Record 11 of Set 4 | puerto escondido
# Processing Record 12 of Set 4 | hobyo
# Processing Record 13 of Set 4 | rajur
# Processing Record 14 of Set 4 | gat
# Processing Record 15 of Set 4 | visnes
# Processing Record 16 of Set 4 | tessalit
# Processing Record 17 of Set 4 | adrar
# Processing Record 18 of Set 4 | cordoba
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | jagdalpur
# Processing Record 21 of Set 4 | lagos
# Processing Record 22 of Set 4 | oranjestad
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | sao felix do xingu
# Processing Record 25 of Set 4 | buraydah
# Processing Record 26 of Set 4 | allanmyo
# City not found. Skipping...
# Processing Record 27 of Set 4 | vestmannaeyjar
# Processing Record 28 of Set 4 | los llanos de aridane
# Processing Record 29 of Set 4 | mingshui
# Processing Record 30 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 4 | iqaluit
# Processing Record 32 of Set 4 | hasaki
# Processing Record 33 of Set 4 | katsuura
# Processing Record 34 of Set 4 | nan
# Processing Record 35 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | mayo
# Processing Record 38 of Set 4 | kortkeros
# Processing Record 39 of Set 4 | rio gallegos
# City not found. Skipping...
# Processing Record 40 of Set 4 | hun
# Processing Record 41 of Set 4 | maroua
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | vawkavysk
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | kemi
# City not found. Skipping...
# Processing Record 46 of Set 4 | ilulissat
# Processing Record 47 of Set 4 | dingle
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | berezovyy
# City not found. Skipping...
# Processing Record 0 of Set 5 | isangel
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | horsham
# Processing Record 3 of Set 5 | traverse city
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | moree
# Processing Record 6 of Set 5 | villamontes
# Processing Record 7 of Set 5 | vryburg
# Processing Record 8 of Set 5 | tura
# Processing Record 9 of Set 5 | ahipara
# Processing Record 10 of Set 5 | banjar
# Processing Record 11 of Set 5 | limbang
# Processing Record 12 of Set 5 | yankton
# Processing Record 13 of Set 5 | fortuna
# Processing Record 14 of Set 5 | inhambane
# Processing Record 15 of Set 5 | ponta do sol
# Processing Record 16 of Set 5 | port blair
# Processing Record 17 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 5 | exu
# Processing Record 19 of Set 5 | moussoro
# Processing Record 20 of Set 5 | progreso
# Processing Record 21 of Set 5 | husavik
# Processing Record 22 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 5 | batagay
# Processing Record 24 of Set 5 | kruisfontein
# Processing Record 25 of Set 5 | kudat
# Processing Record 26 of Set 5 | yatou
# Processing Record 27 of Set 5 | yelizovo
# Processing Record 28 of Set 5 | kieta
# Processing Record 29 of Set 5 | honiara
# Processing Record 30 of Set 5 | severo-kurilsk
# Processing Record 31 of Set 5 | oksfjord
# Processing Record 32 of Set 5 | alice springs
# Processing Record 33 of Set 5 | pacifica
# Processing Record 34 of Set 5 | sursk
# Processing Record 35 of Set 5 | georgetown
# Processing Record 36 of Set 5 | mizdah
# Processing Record 37 of Set 5 | iberia
# Processing Record 38 of Set 5 | jiuquan
# Processing Record 39 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 5 | hornepayne
# Processing Record 41 of Set 5 | erzin
# Processing Record 42 of Set 5 | dutse
# Processing Record 43 of Set 5 | deputatskiy
# Processing Record 44 of Set 5 | carnarvon
# Processing Record 45 of Set 5 | mount isa
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | hernani
# Processing Record 48 of Set 5 | veselynove
# Processing Record 49 of Set 5 | labuhan
# Processing Record 0 of Set 6 | itaquyry
# Processing Record 1 of Set 6 | kamaishi
# Processing Record 2 of Set 6 | loiza
# Processing Record 3 of Set 6 | nome
# Processing Record 4 of Set 6 | upernavik
# Processing Record 5 of Set 6 | chegutu
# Processing Record 6 of Set 6 | timbiqui
# Processing Record 7 of Set 6 | savalou
# Processing Record 8 of Set 6 | olafsvik
# Processing Record 9 of Set 6 | kudahuvadhoo
# Processing Record 10 of Set 6 | tynda
# Processing Record 11 of Set 6 | bejar
# Processing Record 12 of Set 6 | melbu
# Processing Record 13 of Set 6 | longyearbyen
# Processing Record 14 of Set 6 | gamba
# Processing Record 15 of Set 6 | reitz
# Processing Record 16 of Set 6 | kurumkan
# Processing Record 17 of Set 6 | bossangoa
# Processing Record 18 of Set 6 | sakakah
# Processing Record 19 of Set 6 | akonolinga
# Processing Record 20 of Set 6 | basco
# Processing Record 21 of Set 6 | aiquile
# Processing Record 22 of Set 6 | nombre de dios
# Processing Record 23 of Set 6 | aykhal
# Processing Record 24 of Set 6 | santa isabel do rio negro
# Processing Record 25 of Set 6 | chifeng
# Processing Record 26 of Set 6 | aberdeen
# Processing Record 27 of Set 6 | sisimiut
# Processing Record 28 of Set 6 | pochutla
# Processing Record 29 of Set 6 | dunedin
# Processing Record 30 of Set 6 | shahr-e babak
# Processing Record 31 of Set 6 | leshukonskoye
# Processing Record 32 of Set 6 | constitucion
# Processing Record 33 of Set 6 | zhigansk
# Processing Record 34 of Set 6 | daru
# Processing Record 35 of Set 6 | biltine
# Processing Record 36 of Set 6 | salalah
# Processing Record 37 of Set 6 | grand gaube
# Processing Record 38 of Set 6 | ostrovnoy
# Processing Record 39 of Set 6 | keti bandar
# Processing Record 40 of Set 6 | elizabeth city
# Processing Record 41 of Set 6 | nizhniy odes
# Processing Record 42 of Set 6 | aksay
# Processing Record 43 of Set 6 | mar del plata
# Processing Record 44 of Set 6 | kochubey
# Processing Record 45 of Set 6 | talnakh
# Processing Record 46 of Set 6 | sorong
# Processing Record 47 of Set 6 | mount gambier
# Processing Record 48 of Set 6 | karratha
# Processing Record 49 of Set 6 | tigzirt
# Processing Record 0 of Set 7 | palu
# Processing Record 1 of Set 7 | xichang
# Processing Record 2 of Set 7 | vila franca do campo
# Processing Record 3 of Set 7 | iranshahr
# Processing Record 4 of Set 7 | tutoia
# Processing Record 5 of Set 7 | broken hill
# Processing Record 6 of Set 7 | tammisaari
# Processing Record 7 of Set 7 | luanda
# Processing Record 8 of Set 7 | flin flon
# Processing Record 9 of Set 7 | sao filipe
# Processing Record 10 of Set 7 | general roca
# Processing Record 11 of Set 7 | corner brook
# Processing Record 12 of Set 7 | hilo
# Processing Record 13 of Set 7 | nabire
# Processing Record 14 of Set 7 | sechura
# Processing Record 15 of Set 7 | phan thiet
# Processing Record 16 of Set 7 | petropavlovka
# Processing Record 17 of Set 7 | boa vista
# Processing Record 18 of Set 7 | sindor
# Processing Record 19 of Set 7 | vostok
# Processing Record 20 of Set 7 | tateyama
# Processing Record 21 of Set 7 | nagato
# Processing Record 22 of Set 7 | usinsk
# Processing Record 23 of Set 7 | vallenar
# Processing Record 24 of Set 7 | mwinilunga
# Processing Record 25 of Set 7 | nanortalik
# Processing Record 26 of Set 7 | mastic beach
# Processing Record 27 of Set 7 | kodiak
# Processing Record 28 of Set 7 | souillac
# Processing Record 29 of Set 7 | lukovetskiy
# Processing Record 30 of Set 7 | aitape
# Processing Record 31 of Set 7 | lake havasu city
# Processing Record 32 of Set 7 | bin qirdan
# Processing Record 33 of Set 7 | lavrentiya
# Processing Record 34 of Set 7 | ust-nera
# Processing Record 35 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 7 | guipavas
# Processing Record 37 of Set 7 | necochea
# Processing Record 38 of Set 7 | sagauli
# Processing Record 39 of Set 7 | kyabe
# Processing Record 40 of Set 7 | beterou
# Processing Record 41 of Set 7 | verkhoyansk
# Processing Record 42 of Set 7 | zacualpan
# Processing Record 43 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 7 | makokou
# Processing Record 45 of Set 7 | cabinda
# Processing Record 46 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 47 of Set 7 | evensk
# Processing Record 48 of Set 7 | dzaoudzi
# Processing Record 49 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 0 of Set 8 | dubbo
# Processing Record 1 of Set 8 | kendari
# Processing Record 2 of Set 8 | mareeba
# Processing Record 3 of Set 8 | tuatapere
# Processing Record 4 of Set 8 | ambon
# Processing Record 5 of Set 8 | oranjemund
# Processing Record 6 of Set 8 | poronaysk
# Processing Record 7 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 8 | san andres
# Processing Record 9 of Set 8 | guerrero negro
# Processing Record 10 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 8 | lorengau
# Processing Record 12 of Set 8 | mezinovskiy
# Processing Record 13 of Set 8 | spring valley
# Processing Record 14 of Set 8 | kushmurun
# Processing Record 15 of Set 8 | pasaje
# Processing Record 16 of Set 8 | saint-francois
# Processing Record 17 of Set 8 | rorvik
# Processing Record 18 of Set 8 | luena
# Processing Record 19 of Set 8 | nyurba
# Processing Record 20 of Set 8 | makinsk
# Processing Record 21 of Set 8 | wamba
# Processing Record 22 of Set 8 | emerald
# Processing Record 23 of Set 8 | brigantine
# Processing Record 24 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 8 | aloleng
# Processing Record 26 of Set 8 | laguna
# Processing Record 27 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 28 of Set 8 | cheyenne
# Processing Record 29 of Set 8 | half moon bay
# Processing Record 30 of Set 8 | lahaina
# Processing Record 31 of Set 8 | bato
# Processing Record 32 of Set 8 | pakxan
# Processing Record 33 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 34 of Set 8 | tuktoyaktuk
# Processing Record 35 of Set 8 | flinders
# Processing Record 36 of Set 8 | birao
# Processing Record 37 of Set 8 | xining
# Processing Record 38 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 39 of Set 8 | las juntas
# Processing Record 40 of Set 8 | zarubino
# Processing Record 41 of Set 8 | mehamn
# Processing Record 42 of Set 8 | uusikaupunki
# Processing Record 43 of Set 8 | cayenne
# Processing Record 44 of Set 8 | ust-kan
# Processing Record 45 of Set 8 | klaeng
# Processing Record 46 of Set 8 | buhovo
# Processing Record 47 of Set 8 | vangaindrano
# Processing Record 48 of Set 8 | makakilo city
# Processing Record 49 of Set 8 | stephenville
# Processing Record 0 of Set 9 | padang
# Processing Record 1 of Set 9 | fairbanks
# Processing Record 2 of Set 9 | mackay
# Processing Record 3 of Set 9 | tual
# Processing Record 4 of Set 9 | invermere
# Processing Record 5 of Set 9 | west plains
# Processing Record 6 of Set 9 | pisco
# Processing Record 7 of Set 9 | kushiro
# Processing Record 8 of Set 9 | kemijarvi
# Processing Record 9 of Set 9 | san juan
# Processing Record 10 of Set 9 | nelson bay
# Processing Record 11 of Set 9 | cherskiy
# Processing Record 12 of Set 9 | maceio
# Processing Record 13 of Set 9 | kota kinabalu
# Processing Record 14 of Set 9 | vanimo
# Processing Record 15 of Set 9 | neuquen
# Processing Record 16 of Set 9 | byron bay
# Processing Record 17 of Set 9 | novokayakent
# Processing Record 18 of Set 9 | abakaliki
# Processing Record 19 of Set 9 | chapais
# Processing Record 20 of Set 9 | gagesti
# Processing Record 21 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 22 of Set 9 | dovolnoye
# Processing Record 23 of Set 9 | vreed en hoop
# City not found. Skipping...
# Processing Record 24 of Set 9 | mahajanga
# Processing Record 25 of Set 9 | kungur
# Processing Record 26 of Set 9 | tomatlan
# Processing Record 27 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 9 | avera
# Processing Record 29 of Set 9 | fort nelson
# Processing Record 30 of Set 9 | tombouctou
# Processing Record 31 of Set 9 | anori
# Processing Record 32 of Set 9 | greenwood
# Processing Record 33 of Set 9 | sawtell
# Processing Record 34 of Set 9 | ixtapa
# Processing Record 35 of Set 9 | kayes
# Processing Record 36 of Set 9 | bulgan
# Processing Record 37 of Set 9 | vanavara
# Processing Record 38 of Set 9 | bilibino
# Processing Record 39 of Set 9 | atexcatzingo
# Processing Record 40 of Set 9 | jamiltepec
# Processing Record 41 of Set 9 | virginia beach
# Processing Record 42 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 9 | moss vale
# Processing Record 44 of Set 9 | qena
# Processing Record 45 of Set 9 | mvangue
# Processing Record 46 of Set 9 | san jeronimo
# Processing Record 47 of Set 9 | atbasar
# Processing Record 48 of Set 9 | manaus
# Processing Record 49 of Set 9 | bilma
# Processing Record 0 of Set 10 | the valley
# Processing Record 1 of Set 10 | omsukchan
# Processing Record 2 of Set 10 | hirara
# Processing Record 3 of Set 10 | fushan
# Processing Record 4 of Set 10 | hermiston
# Processing Record 5 of Set 10 | fujin
# Processing Record 6 of Set 10 | basar
# Processing Record 7 of Set 10 | touros
# Processing Record 8 of Set 10 | quinapondan
# Processing Record 9 of Set 10 | penzance
# Processing Record 10 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 10 | buala
# Processing Record 12 of Set 10 | asyut
# Processing Record 13 of Set 10 | namatanai
# Processing Record 14 of Set 10 | saint-joseph
# Processing Record 15 of Set 10 | popondetta
# Processing Record 16 of Set 10 | shangrao
# Processing Record 17 of Set 10 | meadow lake
# Processing Record 18 of Set 10 | kakonko
# Processing Record 19 of Set 10 | sibolga
# Processing Record 20 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 21 of Set 10 | guatire
# Processing Record 22 of Set 10 | kaohsiung
# Processing Record 23 of Set 10 | duluth
# Processing Record 24 of Set 10 | tucuman
# Processing Record 25 of Set 10 | yenotayevka
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | luba
# Processing Record 28 of Set 10 | paciran
# Processing Record 29 of Set 10 | tignere
# Processing Record 30 of Set 10 | bambous virieux
# Processing Record 31 of Set 10 | saint-augustin
# Processing Record 32 of Set 10 | goryachegorsk
# Processing Record 33 of Set 10 | edremit
# Processing Record 34 of Set 10 | santa luzia
# Processing Record 35 of Set 10 | antofagasta
# Processing Record 36 of Set 10 | broome
# Processing Record 37 of Set 10 | la primavera
# Processing Record 38 of Set 10 | faya
# Processing Record 39 of Set 10 | mancio lima
# Processing Record 40 of Set 10 | kilimatinde
# Processing Record 41 of Set 10 | parintins
# Processing Record 42 of Set 10 | dhidhdhoo
# Processing Record 43 of Set 10 | iwanai
# Processing Record 44 of Set 10 | pahrump
# Processing Record 45 of Set 10 | jalu
# Processing Record 46 of Set 10 | port hardy
# Processing Record 47 of Set 10 | cotonou
# Processing Record 48 of Set 10 | fort-shevchenko
# Processing Record 49 of Set 10 | meulaboh
# Processing Record 0 of Set 11 | yar-sale
# Processing Record 1 of Set 11 | cabo san lucas
# Processing Record 2 of Set 11 | san vicente
# Processing Record 3 of Set 11 | keelung
# Processing Record 4 of Set 11 | saint-leu
# Processing Record 5 of Set 11 | beloha
# Processing Record 6 of Set 11 | ponta delgada
# Processing Record 7 of Set 11 | kokkola
# Processing Record 8 of Set 11 | tremedal
# Processing Record 9 of Set 11 | mariental
# Processing Record 10 of Set 11 | valdivia
# Processing Record 11 of Set 11 | samarai
# Processing Record 12 of Set 11 | yelandur
# Processing Record 13 of Set 11 | springbok
# Processing Record 14 of Set 11 | belton
# Processing Record 15 of Set 11 | ambilobe
# Processing Record 16 of Set 11 | belyy yar
# Processing Record 17 of Set 11 | wad rawah
# Processing Record 18 of Set 11 | aklavik
# Processing Record 19 of Set 11 | srednekolymsk
# Processing Record 20 of Set 11 | antalaha
# Processing Record 21 of Set 11 | pemangkat
# Processing Record 22 of Set 11 | urumqi
# Processing Record 23 of Set 11 | mahon
# Processing Record 24 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 11 | coquimbo
# Processing Record 26 of Set 11 | saint-georges
# Processing Record 27 of Set 11 | capanema
# Processing Record 28 of Set 11 | naze
# Processing Record 29 of Set 11 | ozernovskiy
# Processing Record 30 of Set 11 | coahuayana
# Processing Record 31 of Set 11 | havelock
# Processing Record 32 of Set 11 | nemuro
# Processing Record 33 of Set 11 | umm kaddadah
# Processing Record 34 of Set 11 | hit
# Processing Record 35 of Set 11 | kaitangata
# Processing Record 36 of Set 11 | santa ana
# Processing Record 37 of Set 11 | port lincoln
# Processing Record 38 of Set 11 | bouillante
# Processing Record 39 of Set 11 | bekhtery
# Processing Record 40 of Set 11 | khani
# Processing Record 41 of Set 11 | solnechnyy
# Processing Record 42 of Set 11 | carutapera
# Processing Record 43 of Set 11 | niesky
# Processing Record 44 of Set 11 | woodland
# Processing Record 45 of Set 11 | yeppoon
# Processing Record 46 of Set 11 | santa quiteria
# Processing Record 47 of Set 11 | linchuan
# City not found. Skipping...
# Processing Record 48 of Set 11 | channel-port aux basques
# Processing Record 49 of Set 11 | huarmey
# Processing Record 0 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 12 | xadani
# City not found. Skipping...
# Processing Record 2 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 3 of Set 12 | opuwo
# Processing Record 4 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 12 | tilichiki
# Processing Record 6 of Set 12 | tecoanapa
# Processing Record 7 of Set 12 | barahona
# Processing Record 8 of Set 12 | roma
# Processing Record 9 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 12 | marquette
# Processing Record 11 of Set 12 | kununurra
# Processing Record 12 of Set 12 | montego bay
# Processing Record 13 of Set 12 | hay river
# Processing Record 14 of Set 12 | klamath falls
# Processing Record 15 of Set 12 | rio pardo de minas
# Processing Record 16 of Set 12 | januaria
# Processing Record 17 of Set 12 | nauta
# Processing Record 18 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 12 | villa carlos paz
# Processing Record 20 of Set 12 | tautira
# Processing Record 21 of Set 12 | henties bay
# Processing Record 22 of Set 12 | tiarei
# Processing Record 23 of Set 12 | barcelos
# Processing Record 24 of Set 12 | lagoa
# Processing Record 25 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 12 | glossa
# Processing Record 27 of Set 12 | bezhanitsy
# Processing Record 28 of Set 12 | san jose
# Processing Record 29 of Set 12 | mangrol
# Processing Record 30 of Set 12 | kontagora
# Processing Record 31 of Set 12 | rundu
# Processing Record 32 of Set 12 | quang ngai
# Processing Record 33 of Set 12 | at-bashi
# Processing Record 34 of Set 12 | viseu
# Processing Record 35 of Set 12 | porto velho
# Processing Record 36 of Set 12 | la tuque
# Processing Record 37 of Set 12 | bayji
# Processing Record 38 of Set 12 | dharchula
# Processing Record 39 of Set 12 | puerto carreno
# Processing Record 40 of Set 12 | lerwick
# Processing Record 41 of Set 12 | kargasok
# Processing Record 42 of Set 12 | socorro
# Processing Record 43 of Set 12 | voskresenskoye
# Processing Record 44 of Set 12 | hualmay
# Processing Record 45 of Set 12 | hamilton
# Processing Record 46 of Set 12 | urengoy
# Processing Record 47 of Set 12 | port alberni
# Processing Record 48 of Set 12 | belmonte
# Processing Record 49 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 0 of Set 13 | amga
# Processing Record 1 of Set 13 | leh
# Processing Record 2 of Set 13 | saint-michel-des-saints
# Processing Record 3 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 13 | lazaro cardenas
# Processing Record 5 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 6 of Set 13 | san quintin
# Processing Record 7 of Set 13 | kedrovyy
# Processing Record 8 of Set 13 | nakusp
# Processing Record 9 of Set 13 | yarada
# Processing Record 10 of Set 13 | liverpool
# Processing Record 11 of Set 13 | road town
# Processing Record 12 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 13 | calvinia
# Processing Record 14 of Set 13 | hailey
# Processing Record 15 of Set 13 | camacha
# Processing Record 16 of Set 13 | eyl
# Processing Record 17 of Set 13 | narok
# Processing Record 18 of Set 13 | baoro
# Processing Record 19 of Set 13 | beringovskiy
# Processing Record 20 of Set 13 | ormara
# Processing Record 21 of Set 13 | el bagre
# Processing Record 22 of Set 13 | swan river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 569

# %%
# Convert the cities weather data into a Pandas DataFrame
#weather_dict = {
   # 'City': name,
  #  'Country': ctry,
   # 'Date': date,
   # 'Lat': lat,
   # 'Lng': lng,
   # 'Cloudiness': cloud,
   # 'Humidity': humi,
   # 'Max Temp': maxtemp,
   # 'Wind Speed': wind
#}

#WeatherPy_df=pd.DataFrame(weather_dict)

city_data_df = pd.DataFrame(city_data)

# Show Record Count
#WeatherPy_df.count()
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          hobart -42.8794  147.3294     62.06        66          75
# 1         redmond  47.6740 -122.1215     49.05        79          56
# 2  port macquarie -31.4333  152.9167     74.89        66          86
# 3           lujan -34.5703  -59.1050     85.05        55           0
# 4       busselton -33.6500  115.3333     72.36        57           0
# 5          atuona  -9.8000 -139.0333     78.93        76          19
# 6     la libertad  -2.2333  -80.9000     79.14        76           6
# 7         mataura -46.1927  168.8643     54.48        75          83
# 8          matara   5.9485   80.5353     73.78        92          73
# 9         opunake -39.4556  173.8583     68.61        65           4
#
#    Wind Speed Country        Date
# 0       13.80      AU  1675818178
# 1        7.00      US  1675818179
# 2        4.70      AU  1675817932
# 3        1.01      AR  1675818011
# 4        8.30      AU  1675818179
# 5       15.17      PF  1675818179
# 6        7.11      EC  1675818180
# 7       10.45      NZ  1675818180
# 8        6.64      LK  1675818180
# 9       16.82      NZ  1675818181

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
WeatherPy_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                hobart -42.8794  147.3294     62.06        66          75
# 1               redmond  47.6740 -122.1215     49.05        79          56
# 2        port macquarie -31.4333  152.9167     74.89        66          86
# 3                 lujan -34.5703  -59.1050     85.05        55           0
# 4             busselton -33.6500  115.3333     72.36        57           0
#
#          Wind Speed Country        Date
# City_ID
# 0             13.80      AU  1675818178
# 1              7.00      US  1675818179
# 2              4.70      AU  1675817932
# 3              1.01      AR  1675818011
# 4              8.30      AU  1675818179

# %% [markdown]
# # Create the Scatter Plots Requested
#
# # Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
# YOUR CODE HERE
import datetime as dt

plt.scatter(WeatherPy_df['Lat'],WeatherPy_df['Max Temp'], facecolor='royalblue', 
            edgecolors='black', marker="o", alpha=0.75)


plt.title('City Latitude vs. Max Temperature' + ' (' + str(dt.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid(b=True, which='major',axis="both", linestyle="-", color="grey")


# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()
# Out:
# C:\Users\radrs01\AppData\Local\Temp\ipykernel_19296\1557510597.py:13: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major',axis="both", linestyle="-", color="grey")

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

# Incorporate the other graph properties

plt.scatter(WeatherPy_df['Lat'],WeatherPy_df['Humidity'], facecolor='royalblue', 
            edgecolors='black', marker="o", alpha=0.75)


# Set titles
plt.title('City Latitude vs. Humidity' + ' (' + str(dt.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(b=True, which='major',axis="both", linestyle="-", color="grey")

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()
# Out:
# C:\Users\radrs01\AppData\Local\Temp\ipykernel_19296\3276706624.py:13: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major',axis="both", linestyle="-", color="grey")

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(WeatherPy_df['Lat'],WeatherPy_df['Cloudiness'], facecolor='royalblue', 
            edgecolors='black', marker="o", alpha=0.75)

# Incorporate the other graph properties
# Set titles
plt.title('City Latitude vs. Cloudiness' + ' (' + str(dt.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(b=True, which='major',axis="both", linestyle="-", color="grey")


# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()
# Out:
# C:\Users\radrs01\AppData\Local\Temp\ipykernel_19296\3950639158.py:10: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major',axis="both", linestyle="-", color="grey")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

plt.scatter(WeatherPy_df['Lat'],WeatherPy_df['Wind Speed'], facecolor='royalblue', 
            edgecolors='black', marker="o", alpha=0.75)

# Incorporate the other graph properties
# Set titles
plt.title('City Latitude vs. Wind Speed' + ' (' + str(dt.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(b=True, which='major',axis="both", linestyle="-", color="grey")

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()
# Out:
# C:\Users\radrs01\AppData\Local\Temp\ipykernel_19296\2256365250.py:11: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major',axis="both", linestyle="-", color="grey")

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
weather_data_north = WeatherPy_df[WeatherPy_df['Lat'] >= 0]

# Display sample data
weather_data_north.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              redmond  47.6740 -122.1215     49.05        79          56
# 8               matara   5.9485   80.5353     73.78        92          73
# 10       puerto madero  14.7208  -92.4215     77.20        88           0
# 12                nuuk  64.1835  -51.7216      7.88        78         100
# 13             svetlyy  54.6750   20.1347     33.85        81         100
#
#          Wind Speed Country        Date
# City_ID
# 1              7.00      US  1675818179
# 8              6.64      LK  1675818180
# 10             2.30      MX  1675818181
# 12             5.01      GL  1675818183
# 13            10.63      RU  1675818184

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
weather_data_south = WeatherPy_df[WeatherPy_df['Lat'] < 0]

# Display sample data
weather_data_south.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                hobart -42.8794  147.3294     62.06        66          75
# 2        port macquarie -31.4333  152.9167     74.89        66          86
# 3                 lujan -34.5703  -59.1050     85.05        55           0
# 4             busselton -33.6500  115.3333     72.36        57           0
# 5                atuona  -9.8000 -139.0333     78.93        76          19
#
#          Wind Speed Country        Date
# City_ID
# 0             13.80      AU  1675818178
# 2              4.70      AU  1675817932
# 3              1.01      AR  1675818011
# 4              8.30      AU  1675818179
# 5             15.17      PF  1675818179

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))


# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temperature (F)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(0, 0), fontsize=18, color='darkred')
#plt.grid(False)


# Print r-squared value:
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: -0.862024602516234

# %%
# Linear regression on Southern Hemisphere
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq2 = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temperature (F)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq2,(-30, 50),fontsize=18, color='darkred')
#plt.grid(False)



# Print r-squared value:
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.39817604205805396

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude', fontsize=20)
plt.ylabel('Humidity (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(51,6),fontsize=18, color='darkred')
#plt.grid(False)


# Print r-squared value:
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.3902799326013711

# %%
# Southern Hemisphere

plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude', fontsize=20)
plt.ylabel('Humidity (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-50,40), fontsize=18, color='darkred')
#plt.grid(False)



# Print r-squared value:
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.4616105351938202

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(35,25), fontsize=18, color='darkred')
#plt.grid(False)



# Print r-squared value:
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.18538409246994492

# %%
# Southern Hemisphere
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-56,8), fontsize=18, color='darkred')
#plt.grid(False)


# Print r-squared value:
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.39429188588248665

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Wind Speed']

# Perform a linear regression for wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed (mph)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(0,30), fontsize=18, color='darkred')
#plt.grid(False)



# Print r-squared value:
print(f'The r-value is: {rvalue}')

plt.show()
# Out:
# The r-value is: 0.09368384686280465

# %%
# Southern Hemisphere
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Wind Speed']

# Perform a linear regression on wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed (mph)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-19.5,21), fontsize=18, color='darkred')
#plt.grid(False)


# Print r-squared value:
print(f'The r-squared is: {rvalue}')

plt.show()
# Out:
# The r-squared is: -0.3430536272053852

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
